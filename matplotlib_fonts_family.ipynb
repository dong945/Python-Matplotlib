# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# Font
mpl.rcParams["font.sans-serif"] = ["SimHei"]
mpl.rcParams["axes.unicode_minus"] = False
# Data
tick_label = ["台北市","台南市","高雄市","台中市","桃園市","新北市","宜蘭縣","苗栗縣","彰化縣"]
y = [948,615,2499,885,240,1393,214,384,242]

plt.bar(range(len(tick_label)), y, align = "center", color = "b", tick_label = tick_label, alpha = 0.6)

plt.xlabel("負債縣市")
plt.ylabel("負債金額(單位:億)")
plt.title("107年5月底")

plt.show()
